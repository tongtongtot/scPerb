# %%
import scanpy as sc
import matplotlib
import os

# %%
matplotlib.rcParams['pdf.fonttype'] = 42

# %%
pbmc_valid_adata = sc.read("../data/valid_pbmc.h5ad")
pbmc_train_adata = sc.read("../data/train_pbmc.h5ad")
hpoly_valid_adata = sc.read("../data/valid_hpoly.h5ad")
hpoly_train_adata = sc.read("../data/train_hpoly.h5ad")
study_valid_adata = sc.read("../data/valid_study.h5ad")
study_train_adata = sc.read("../data/train_study.h5ad")
pbmc_all_data = sc.AnnData.concatenate(pbmc_train_adata,pbmc_valid_adata)
hpoly_all_data = sc.AnnData.concatenate(hpoly_train_adata,hpoly_valid_adata)
study_all_data = sc.AnnData.concatenate(study_train_adata,study_valid_adata)
scperb_pbmc_adata = sc.read("scperb_pbmc_all_data.h5ad")
scperb_hpoly_adata = sc.read("scperb_hpoly_all_data.h5ad")
scperb_study_adata = sc.read("scperb_study_all_data.h5ad")
scgen_pbmc_adata = sc.read("scgen_pbmc_all_data.h5ad")
scgen_hpoly_adata = sc.read("scgen_hpoly_all_data.h5ad")
scgen_study_adata = sc.read("scgen_study_all_data.h5ad")
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
pbmc_ctrl = pbmc_all_data[pbmc_all_data.obs['condition'] == "control"]
hpoly_ctrl = hpoly_all_data[hpoly_all_data.obs['condition'] == "Control"]
study_ctrl = study_all_data[study_all_data.obs['condition'] == "control"]
pbmc_perb = pbmc_all_data[pbmc_all_data.obs['condition'] == "stimulated"]
hpoly_perb = hpoly_all_data[hpoly_all_data.obs['condition'] == "Hpoly.Day10"]
study_perb = study_all_data[study_all_data.obs['condition'] == "stimulated"]
print(pbmc_ctrl)
print(pbmc_perb)
print("--pbmc--")
print(hpoly_ctrl)
print(hpoly_perb)
print("--hploy--")
print(study_ctrl)
print(study_perb)
print("--study--")
# Out:
# View of AnnData object with n_obs × n_vars = 8943 × 6998
#     obs: 'condition', 'n_counts', 'n_genes', 'mt_frac', 'cell_type', 'batch'
#     var: 'gene_symbol', 'n_cells'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
# View of AnnData object with n_obs × n_vars = 9925 × 6998
#     obs: 'condition', 'n_counts', 'n_genes', 'mt_frac', 'cell_type', 'batch'
#     var: 'gene_symbol', 'n_cells'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
# --pbmc--
# View of AnnData object with n_obs × n_vars = 3240 × 7000
#     obs: 'batch', 'barcode', 'condition', 'cell_label', 'n_counts', 'n_genes', 'mt_frac'
#     var: 'means', 'dispersions', 'dispersions_norm'
#     obsm: 'X_pca', 'X_umap'
# View of AnnData object with n_obs × n_vars = 2711 × 7000
#     obs: 'batch', 'barcode', 'condition', 'cell_label', 'n_counts', 'n_genes', 'mt_frac'
#     var: 'means', 'dispersions', 'dispersions_norm'
#     obsm: 'X_pca', 'X_umap'
# --hploy--
# View of AnnData object with n_obs × n_vars = 8007 × 7000
#     obs: 'cell_type', 'condition', 'mt_frac', 'n_counts', 'n_genes', 'percent_mito', 'study', 'batch'
#     var: 'means', 'dispersions', 'dispersions_norm', 'gene_symbol-0', 'n_cells-0', 'n_cells-1'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
# View of AnnData object with n_obs × n_vars = 8886 × 7000
#     obs: 'cell_type', 'condition', 'mt_frac', 'n_counts', 'n_genes', 'percent_mito', 'study', 'batch'
#     var: 'means', 'dispersions', 'dispersions_norm', 'gene_symbol-0', 'n_cells-0', 'n_cells-1'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
# --study--

# %%
def get_name(name):
    name = name[:5]
    condition = {
        "stim": "stimulated",
        "pred": "pred",
        "ctrl": "control",
        "cell_type_key": "cell_type",
    }
    if name == 'pbmc_' or name == 'pbmc':
        condition = {
            "stim": "stimulated",
            "pred": "pred",
            "ctrl": "control",
            "cell_type_key": "cell_type",
        }
    elif name == 'hpoly':
        condition = {
            "stim": "Hpoly.Day10",
            "pred": "pred",
            "ctrl": "Control",
            "cell_type_key": "cell_label",
        }
    elif name == 'study':
        condition = {
            "stim": "stimulated",
            "pred": "pred",
            "ctrl": "control",
            "cell_type_key": "cell_type",
        }
    else:
        condition = {
            "stim": "stimulated",
            "pred": "pred",
            "ctrl": "control",
            "cell_type_key": "cell_type",
        }
        
    return condition

# %%
names = {
    "pbmc": ['B', 'CD4T', 'CD8T', 'CD14+Mono', 'Dendritic', 'FCGR3A+Mono', 'NK'],
    "hpoly": ['Endocrine', 'Enterocyte', 'Enterocyte.Progenitor', 'Goblet', 'Stem', 'TA', 'TA.Early', 'Tuft'],
    "study": ['B', 'CD4T', 'CD8T', 'CD14+Mono', 'Dendritic', 'FCGR3A+Mono', 'NK'],
}

# %%
def get_diff_genes(adata, name):
    conditions = get_name(name)
    sc.tl.rank_genes_groups(adata, groupby="condition", n_genes=100, method="wilcoxon")
    diff_genes = adata.uns["rank_genes_groups"]["names"][conditions["stim"]].tolist()[:50] + adata.uns["rank_genes_groups"]["names"][conditions["ctrl"]].tolist()[:50]
    return diff_genes

# %%
def plot_umap(adata, name, cell_type = ""):
#     adata = adata[~(adata.obs['condition'] == 'stimulated')]
#     print(adata.obs['condition'])
    diff_genes = get_diff_genes(adata, name)
    print(diff_genes[0])
    conditions = get_name(name)
#     matplotlib.rcParams.update(matplotlib.rcParamsDefault)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)
#     sc.pl.umap(adata, color = ['condition'], title=f"{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_{cell_type}_{name}_condition.pdf")
#     sc.pl.umap(adata, color = [conditions['cell_type_key']], title=f"{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_{cell_type}_{name}_celltype.pdf")
#     sc.pl.umap(adata, color = [diff_genes[0]], title=f"{diff_genes[0]}_{cell_type}_{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_{cell_type}_{name}_{diff_genes[0]}.pdf")
    sc.pl.umap(adata, color = ["condition"], title=f"{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_condition_{name}_for_ppt.pdf")
    sc.pl.umap(adata, color = [conditions['cell_type_key']], title=f"{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_celltype_{name}_for_ppt.pdf")
#     sc.pl.umap(adata, color = [diff_genes[0]], title=f"{diff_genes[0]}_{cell_type}_{name}", frameon=True, palette=matplotlib.rcParams["axes.prop_cycle"], legend_fontsize=10, save =f"/umap_{name}_for_ppt.pdf")

# %%
# plot_umap(pbmc_valid_adata, "pbmc_valid")
# plot_umap(pbmc_train_adata, "pbmc_train")
# plot_umap(hpoly_valid_adata, "hpoly_valid")
# plot_umap(hpoly_train_adata, "hpoly_train")
# plot_umap(study_valid_adata, "study_valid")
# plot_umap(study_train_adata, "study_train")

# %%
plot_umap(pbmc_all_data, "pbmc_Kang")
plot_umap(hpoly_all_data, "hpoly")
plot_umap(study_all_data, "pbmc_Zheng")
# Out:
# ISG15
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_Kang_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_Kang_for_ppt.pdf
# Defa24
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# ISG15
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_Zheng_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_Zheng_for_ppt.pdf

# %%
# plot_umap(scperb_pbmc_adata, "pbmc_Kang")
# plot_umap(scperb_hpoly_adata, "hpoly")
# plot_umap(scperb_study_adata, "pbmc_Zheng")

# %%
# import numpy as np
ctrl_pbmc = scperb_pbmc_adata[scperb_pbmc_adata.obs['condition'] == 'control']
ctrl_pbmc[:,"IFI6"].X.mean()
# Out:
# 0.15038416

# %%
pred_pbmc = scperb_pbmc_adata[scperb_pbmc_adata.obs['condition'] == 'pred']
pred_pbmc[:,"IFI6"].X.mean()
# Out:
# 1.7168136

# %%
# plot_umap(scperb_pbmc_adata, "pbmc_scgen")
# plot_umap(scperb_hpoly_adata, "hpoly_scgen")
# plot_umap(scperb_study_adata, "study_scgen")

# %%
def plot_cell_type_umap(adata, cell_type, name):
    condition = get_name(name)
    cell_type_adata = adata[adata.obs[condition['cell_type_key']] == cell_type]
    plot_umap(cell_type_adata, name, cell_type)

# %%
def plot_all_cell_umap(adata, name):
    for cell_type in names[name]:
        plot_cell_type_umap(adata, cell_type,name)

# %%
plot_all_cell_umap(scperb_pbmc_adata, "pbmc")
plot_all_cell_umap(scperb_hpoly_adata, "hpoly")
plot_all_cell_umap(scperb_study_adata, "study")
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# IFI6
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# IFIT3
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# IFI6
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# CXCL11
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# IFITM3
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# ISG15
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# B2M
# WARNING: You’re trying to run this on 6998 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_pbmc_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_pbmc_for_ppt.pdf
# Maged1
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# Reg3b
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# Gpx2
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# Reg3b
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# Reg3b
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# Dmbt1
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# Gpx2
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# H2.K1
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_hpoly_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_hpoly_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# IFIT1
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# IFI6
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# ISG20
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# APOBEC3A
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# IFITM3
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# CXCL10
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
# ISG20
# WARNING: You’re trying to run this on 7000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:580: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = {}
# WARNING: saving figure to file figures/umap/umap_condition_study_for_ppt.pdf
# WARNING: saving figure to file figures/umap/umap_celltype_study_for_ppt.pdf
