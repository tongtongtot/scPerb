# %%
import scanpy as sc
import anndata as adata
from scipy import sparse

# %%
def adata2numpy(adata):
    if sparse.issparse(adata.X):
        return adata.X.A
    else:
        return adata.X

# %%
names = {
    "pbmc": ['B', 'CD4T', 'CD8T', 'CD14+Mono', 'Dendritic', 'FCGR3A+Mono', 'NK'],
    "hpoly": ['Endocrine', 'Enterocyte', 'Enterocyte.Progenitor', 'Goblet', 'Stem', 'TA', 'TA.Early', 'Tuft'],
    "study": ['B', 'CD4T', 'CD8T', 'CD14+Mono', 'Dendritic', 'FCGR3A+Mono', 'NK'],
}
keys = {
    "pbmc": ['stimulated', 'control', 'pred', 'cell_type'],
    "hpoly": ['Hpoly.Day10', 'Control', 'pred', 'cell_label'],
    "study": ['stimulated', 'control', 'pred', 'cell_type'],
}
valid = {
    "pbmc": sc.read("../data/valid_pbmc.h5ad"),
    "hpoly": sc.read("../data/valid_hpoly.h5ad"),
    "study": sc.read("../data/valid_study.h5ad"),
}
train = {
    "pbmc": sc.read("../data/train_pbmc.h5ad"),
    "hpoly": sc.read("../data/train_hpoly.h5ad"),
    "study": sc.read("../data/train_study.h5ad"),
}
stim = {
    "pbmc" : valid['pbmc'][valid['pbmc'].obs['condition'] == keys['pbmc'][0]],
    "hpoly" : valid['hpoly'][valid['hpoly'].obs['condition'] == keys['hpoly'][0]],
    "study" : valid['study'][valid['study'].obs['condition'] == keys['study'][0]],
}
ctrl = {
    "pbmc" : valid['pbmc'][valid['pbmc'].obs['condition'] == keys['pbmc'][1]],
    "hpoly" : valid['hpoly'][valid['hpoly'].obs['condition'] == keys['hpoly'][1]],
    "study" : valid['study'][valid['study'].obs['condition'] == keys['study'][1]],
}
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
print(train["pbmc"])
print(train["hpoly"])
print(train["study"])
print(valid["pbmc"])
print(valid["hpoly"])
print(valid["study"])
# Out:
# AnnData object with n_obs × n_vars = 16893 × 6998
#     obs: 'condition', 'n_counts', 'n_genes', 'mt_frac', 'cell_type'
#     var: 'gene_symbol', 'n_cells'
#     uns: 'cell_type_colors', 'condition_colors', 'neighbors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     obsp: 'distances', 'connectivities'
# AnnData object with n_obs × n_vars = 5059 × 7000
#     obs: 'batch', 'barcode', 'condition', 'cell_label', 'n_counts', 'n_genes', 'mt_frac'
#     var: 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_label_colors', 'condition_colors', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'
# AnnData object with n_obs × n_vars = 14893 × 7000
#     obs: 'cell_type', 'condition', 'mt_frac', 'n_counts', 'n_genes', 'percent_mito', 'study'
#     var: 'gene_symbol-0', 'n_cells-0', 'n_cells-1', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_type_colors', 'condition_colors', 'neighbors', 'pca', 'study_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# AnnData object with n_obs × n_vars = 1975 × 6998
#     obs: 'condition', 'n_counts', 'n_genes', 'mt_frac', 'cell_type'
#     var: 'gene_symbol', 'n_cells'
#     uns: 'cell_type_colors', 'condition_colors', 'neighbors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     obsp: 'distances', 'connectivities'
# AnnData object with n_obs × n_vars = 892 × 7000
#     obs: 'batch', 'barcode', 'condition', 'cell_label', 'n_counts', 'n_genes', 'mt_frac'
#     var: 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_label_colors', 'condition_colors', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'
# AnnData object with n_obs × n_vars = 2000 × 7000
#     obs: 'cell_type', 'condition', 'mt_frac', 'n_counts', 'n_genes', 'percent_mito', 'study'
#     var: 'gene_symbol-0', 'n_cells-0', 'n_cells-1', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_type_colors', 'condition_colors', 'neighbors', 'pca', 'study_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
def normalize(adata, name = 'pbmc'):
    pred_adata = adata[adata.obs['condition'] == 'pred']
    all_adata = pred_adata.concatenate(ctrl[name], stim[name])
    return all_adata

# %%
def get_all_data(name):
    now = []
    for cell_type in names[name]:
        now_adata = sc.read(f"scperb/{name}/model_{cell_type}/result.h5ad")
        now.append(now_adata)
    now = adata.concat(now)
    return now

# %%
def view_adata(adata):
    print(adata.obs['condition'])
    pred = adata[adata.obs['condition'] == 'pred']
    print(pred.obs['condition'])
    stim = adata[adata.obs['condition'] == 'stimulated']
    print(stim.obs['condition'])
    ctrl = adata[adata.obs['condition'] == 'control']
    print(ctrl.obs['condition'])

# %%
pbmc_all_data = get_all_data("pbmc")
hpoly_all_data = get_all_data("hpoly")
study_all_data = get_all_data("study")
# view_adata(pbmc_all_data)
view_adata(hpoly_all_data)
# view_adata(study_all_data)
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0    Control
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0    Control
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0    Control
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0    Control
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0    Control
#                                             ...
# 2-2                                           pred
# 3-2                                           pred
# 4-2                                           pred
# 5-2                                           pred
# 6-2                                           pred
# Name: condition, Length: 1396, dtype: category
# Categories (3, object): ['Control', 'Hpoly.Day10', 'pred']
# 0-2    pred
# 1-2    pred
# 2-2    pred
# 3-2    pred
# 4-2    pred
#        ...
# 2-2    pred
# 3-2    pred
# 4-2    pred
# 5-2    pred
# 6-2    pred
# Name: condition, Length: 504, dtype: category
# Categories (1, object): ['pred']
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
pbmc_all_data.write_h5ad("scperb_pbmc_all_data.h5ad")
hpoly_all_data.write_h5ad("scperb_hpoly_all_data.h5ad")
study_all_data.write_h5ad("scperb_study_all_data.h5ad")

# %%
def get_all_scgen_data(name):
    now = []
    for cell_type in names[name]:
        now_adata = sc.read(f"scgen_saved/{name}/model_{cell_type}/result.h5ad")
        now.append(now_adata)
    now = adata.concat(now)
    return now

# %%
pbmc_scgen_all_data = get_all_scgen_data("pbmc")
hpoly_scgen_all_data = get_all_scgen_data("hpoly")
study_scgen_all_data = get_all_scgen_data("study")
view_adata(pbmc_scgen_all_data)
view_adata(hpoly_scgen_all_data)
view_adata(study_scgen_all_data)
# Out:
# index
# TCTAGTTGTCTTAC-1-control-0    control
# GTAAGCACAGAACA-1-control-0    control
# ATCGCGCTATGGTC-1-control-0    control
# ACAACCGATCTTCA-1-control-0    control
# CAATTCACCTCGCT-1-control-0    control
#                                ...
# CGAACATGAAAGCA-1-control-2       pred
# GGTATGACGCTTAG-1-control-2       pred
# AACGTTCTCGCAAT-1-control-2       pred
# GCGAGAGAAGTGCT-1-control-2       pred
# GACCTCACAGATCC-1-control-2       pred
# Name: condition, Length: 2911, dtype: category
# Categories (3, object): ['control', 'pred', 'stimulated']
# index
# TCTAGTTGTCTTAC-1-control-2    pred
# GTAAGCACAGAACA-1-control-2    pred
# ATCGCGCTATGGTC-1-control-2    pred
# ACAACCGATCTTCA-1-control-2    pred
# CAATTCACCTCGCT-1-control-2    pred
#                               ...
# CGAACATGAAAGCA-1-control-2    pred
# GGTATGACGCTTAG-1-control-2    pred
# AACGTTCTCGCAAT-1-control-2    pred
# GCGAGAGAAGTGCT-1-control-2    pred
# GACCTCACAGATCC-1-control-2    pred
# Name: condition, Length: 936, dtype: category
# Categories (1, object): ['pred']
# index
# ATAGATTGTTCACT-1-stimulated-1    stimulated
# CACTTAACCCGTAA-1-stimulated-1    stimulated
# TGAAATTGGACGGA-1-stimulated-1    stimulated
# CTGATACTTAGAGA-1-stimulated-1    stimulated
# AGCCGGACTCCAGA-1-stimulated-1    stimulated
#                                     ...
# AGGGCCACACAGTC-1-stimulated-1    stimulated
# ACAAGAGAGCTTAG-1-stimulated-1    stimulated
# CGGCATCTCACAAC-1-stimulated-1    stimulated
# CGGAGGCTGGGCAA-1-stimulated-1    stimulated
# ACGGCTCTATCGTG-1-stimulated-1    stimulated
# Name: condition, Length: 1039, dtype: category
# Categories (1, object): ['stimulated']
# index
# TCTAGTTGTCTTAC-1-control-0    control
# GTAAGCACAGAACA-1-control-0    control
# ATCGCGCTATGGTC-1-control-0    control
# ACAACCGATCTTCA-1-control-0    control
# CAATTCACCTCGCT-1-control-0    control
#                                ...
# CGAACATGAAAGCA-1-control-0    control
# GGTATGACGCTTAG-1-control-0    control
# AACGTTCTCGCAAT-1-control-0    control
# GCGAGAGAAGTGCT-1-control-0    control
# GACCTCACAGATCC-1-control-0    control
# Name: condition, Length: 936, dtype: category
# Categories (1, object): ['control']
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0    Control
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0    Control
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0    Control
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0    Control
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0    Control
#                                             ...
# B2_AATGGCTGTAGTCG_Control_Tuft-0-2            pred
# B3_TTAGGGACGGCAAG_Control_Tuft-0-2            pred
# B1_GGAGTTTGCTGGTA_Control_Tuft-0-2            pred
# B1_TTACTCGAACGCAT_Control_Tuft-0-2            pred
# B3_GGACAACTATGGTC_Control_Tuft-0-2            pred
# Name: condition, Length: 1396, dtype: category
# Categories (3, object): ['Control', 'Hpoly.Day10', 'pred']
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-2    pred
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-2    pred
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-2    pred
# B1_GATATCCTGTCGTA_Control_Endocrine-0-2    pred
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-2    pred
#                                            ...
# B2_AATGGCTGTAGTCG_Control_Tuft-0-2         pred
# B3_TTAGGGACGGCAAG_Control_Tuft-0-2         pred
# B1_GGAGTTTGCTGGTA_Control_Tuft-0-2         pred
# B1_TTACTCGAACGCAT_Control_Tuft-0-2         pred
# B3_GGACAACTATGGTC_Control_Tuft-0-2         pred
# Name: condition, Length: 504, dtype: category
# Categories (1, object): ['pred']
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# index
# AGGTACACGGATCT-1-control-0-0    control
# CTATGTTGTGGTCA-1-control-0-0    control
# GAAGCTTGATGTGC-1-control-0-0    control
# GACGGCACAATCGC-1-control-0-0    control
# AGGTGTTGTGTTCT-1-control-0-0    control
#                                  ...
# AAACGGCTGGTCAT-1-control-0-2       pred
# CTCATTGATGGTAC-1-control-0-2       pred
# GTTATCTGCACTAG-1-control-0-2       pred
# TCGGTAGAATCTCT-1-control-0-2       pred
# ACATGGTGGATGAA-1-control-0-2       pred
# Name: condition, Length: 2886, dtype: category
# Categories (3, object): ['control', 'pred', 'stimulated']
# index
# AGGTACACGGATCT-1-control-0-2    pred
# CTATGTTGTGGTCA-1-control-0-2    pred
# GAAGCTTGATGTGC-1-control-0-2    pred
# GACGGCACAATCGC-1-control-0-2    pred
# AGGTGTTGTGTTCT-1-control-0-2    pred
#                                 ...
# AAACGGCTGGTCAT-1-control-0-2    pred
# CTCATTGATGGTAC-1-control-0-2    pred
# GTTATCTGCACTAG-1-control-0-2    pred
# TCGGTAGAATCTCT-1-control-0-2    pred
# ACATGGTGGATGAA-1-control-0-2    pred
# Name: condition, Length: 886, dtype: category
# Categories (1, object): ['pred']
# index
# TCCCGAACCGTTGA-1-stimulated-0-1    stimulated
# GATTCGGACGATAC-1-stimulated-0-1    stimulated
# CATTGTTGACGGTT-1-stimulated-0-1    stimulated
# CCAAAGTGCGCTAA-1-stimulated-0-1    stimulated
# CATCAGGAGTATCG-1-stimulated-0-1    stimulated
#                                       ...
# CGGACCGAATGGTC-1-stimulated-0-1    stimulated
# TGCGTAGACGTAAC-1-stimulated-0-1    stimulated
# AGTGACTGCCCTAC-1-stimulated-0-1    stimulated
# ACCGCGGAAAGATG-1-stimulated-0-1    stimulated
# GTTGGATGTGGGAG-1-stimulated-0-1    stimulated
# Name: condition, Length: 1114, dtype: category
# Categories (1, object): ['stimulated']
# index
# AGGTACACGGATCT-1-control-0-0    control
# CTATGTTGTGGTCA-1-control-0-0    control
# GAAGCTTGATGTGC-1-control-0-0    control
# GACGGCACAATCGC-1-control-0-0    control
# AGGTGTTGTGTTCT-1-control-0-0    control
#                                  ...
# AAACGGCTGGTCAT-1-control-0-0    control
# CTCATTGATGGTAC-1-control-0-0    control
# GTTATCTGCACTAG-1-control-0-0    control
# TCGGTAGAATCTCT-1-control-0-0    control
# ACATGGTGGATGAA-1-control-0-0    control
# Name: condition, Length: 886, dtype: category
# Categories (1, object): ['control']

# %%
pbmc_scgen_all_data.write_h5ad("scgen_pbmc_all_data.h5ad")
hpoly_scgen_all_data.write_h5ad("scgen_hpoly_all_data.h5ad")
study_scgen_all_data.write_h5ad("scgen_study_all_data.h5ad")

# %%
def get_all_CVAE_data(name):
    now = []
    for cell_type in names[name]:
        now_adata = sc.read(f"CVAE/{name}/CVAE_{cell_type}.h5ad")
        now_pred = now_adata[now_adata.obs['condition'] == 'pred']
        cell_type_valid = valid[name][(valid[name].obs[keys[name][3]] == cell_type) & (valid[name].obs['condition'] == keys[name][1])]
        now_adata = adata.AnnData(adata2numpy(now_pred), obs=cell_type_valid.obs, var = cell_type_valid.var)
        now_adata.obs[keys[name][3]] = cell_type
        now_adata.obs['condition'] = 'pred'
        now.append(now_adata)
    now = adata.concat(now)
#     now = now.concatenate(stim_pbmc, ctrl_pbmc)
    return now

# %%
pbmc_CVAE_all_data = normalize(get_all_CVAE_data("pbmc"), "pbmc")
hpoly_CVAE_all_data = normalize(get_all_CVAE_data("hpoly"), "hpoly")
study_CVAE_all_data = normalize(get_all_CVAE_data("study"), "study")
# print(pbmc_CVAE_all_data.obs['cell_type'])
# view_adata(pbmc_CVAE_all_data)
view_adata(hpoly_CVAE_all_data)
# view_adata(study_CVAE_all_data)
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0                           pred
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0                           pred
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0                           pred
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0                           pred
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0                           pred
#                                                               ...
# B7_GCAAGACTCTGATG_Hpoly.Day10_TA.Early-1-2                 Hpoly.Day10
# B7_CGCAACCTACACTG_Hpoly.Day10_Stem-1-2                     Hpoly.Day10
# B8_ACTTAGCTGACTAC_Hpoly.Day10_Endocrine-1-2                Hpoly.Day10
# B7_TTCAACACAAAGTG_Hpoly.Day10_Enterocyte.Progenitor-1-2    Hpoly.Day10
# B7_GAGTGTTGAGAATG_Hpoly.Day10_Stem-1-2                     Hpoly.Day10
# Name: condition, Length: 1396, dtype: object
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0    pred
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0    pred
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0    pred
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0    pred
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0    pred
#                                            ...
# B2_AATGGCTGTAGTCG_Control_Tuft-0-0         pred
# B3_TTAGGGACGGCAAG_Control_Tuft-0-0         pred
# B1_GGAGTTTGCTGGTA_Control_Tuft-0-0         pred
# B1_TTACTCGAACGCAT_Control_Tuft-0-0         pred
# B3_GGACAACTATGGTC_Control_Tuft-0-0         pred
# Name: condition, Length: 504, dtype: object
# Series([], Name: condition, dtype: object)
# Series([], Name: condition, dtype: object)

# %%
pbmc_CVAE_all_data.write_h5ad("CVAE_pbmc_all_data.h5ad")
hpoly_CVAE_all_data.write_h5ad("CVAE_hpoly_all_data.h5ad")
study_CVAE_all_data.write_h5ad("CVAE_study_all_data.h5ad")

# %%
def get_all_STGAN_data(name):
    now = []
    for cell_type in names[name]:
        now_adata = sc.read(f"STGAN/{name}/STGAN_{cell_type}.h5ad")
        now_pred = now_adata[now_adata.obs['condition'] == 'pred']     
        cell_type_valid = valid[name][(valid[name].obs[keys[name][3]] == cell_type) & (valid[name].obs['condition'] == keys[name][1])]
        now_adata = adata.AnnData(adata2numpy(now_pred), obs=cell_type_valid.obs, var = cell_type_valid.var)
        now_adata.obs[keys[name][3]] = cell_type
        now_adata.obs['condition'] = 'pred'
        now.append(now_adata)
    now = adata.concat(now)
#     now = now.concatenate(stim_pbmc, ctrl_pbmc)
    return now

# %%
pbmc_STGAN_all_data = normalize(get_all_STGAN_data("pbmc"), "pbmc")
hpoly_STGAN_all_data = normalize(get_all_STGAN_data("hpoly"), "hpoly")
study_STGAN_all_data = normalize(get_all_STGAN_data("study"), "study")
# view_adata(pbmc_STGAN_all_data)
# view_adata(test)
# test1 = test[test.obs['condition'] == 'pred_stim']
# print(test.obs['cell_type'])
# hpoly_STGAN_all_data = get_all_STGAN_data("hpoly")
# study_STGAN_all_data = get_all_STGAN_data("study")
print(pbmc_STGAN_all_data.obs['cell_type'])
# view_adata(pbmc_STGAN_all_data)
# view_adata(hpoly_STGAN_all_data)
# view_adata(study_STGAN_all_data)
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# index
# TCTAGTTGTCTTAC-1-control-0               B
# GTAAGCACAGAACA-1-control-0               B
# ATCGCGCTATGGTC-1-control-0               B
# ACAACCGATCTTCA-1-control-0               B
# CAATTCACCTCGCT-1-control-0               B
#                                    ...
# ATTTGCACGAGAGC-1-stimulated-2    Dendritic
# ACATCACTCAGTCA-1-stimulated-2         CD4T
# GAGTGTTGCACACA-1-stimulated-2            B
# GCGTAATGGGTAAA-1-stimulated-2         CD4T
# TACATAGAGAAGGC-1-stimulated-2         CD4T
# Name: cell_type, Length: 2911, dtype: object

# %%
pbmc_STGAN_all_data.write_h5ad("STGAN_pbmc_all_data.h5ad")
hpoly_STGAN_all_data.write_h5ad("STGAN_hpoly_all_data.h5ad")
study_STGAN_all_data.write_h5ad("STGAN_study_all_data.h5ad")

# %%
def get_all_WGAN_data(name):
    now = []
    for cell_type in names[name]:
        now_adata = sc.read(f"WGAN/{name}/WGAN_{cell_type}.h5ad")
        now.append(now_adata)
    now = adata.concat(now)
    return now

# %%
pbmc_WGAN_all_data = normalize(get_all_WGAN_data("pbmc"), "pbmc")
hpoly_WGAN_all_data = normalize(get_all_WGAN_data("hpoly"), "hpoly")
study_WGAN_all_data = normalize(get_all_WGAN_data("study"), "study")
view_adata(pbmc_WGAN_all_data)
view_adata(hpoly_WGAN_all_data)
view_adata(study_WGAN_all_data)
# Out:
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /Users/tongtongtot/opt/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# 0-0                                    pred
# 1-0                                    pred
# 2-0                                    pred
# 3-0                                    pred
# 4-0                                    pred
#                                     ...
# ATTTGCACGAGAGC-1-stimulated-2    stimulated
# ACATCACTCAGTCA-1-stimulated-2    stimulated
# GAGTGTTGCACACA-1-stimulated-2    stimulated
# GCGTAATGGGTAAA-1-stimulated-2    stimulated
# TACATAGAGAAGGC-1-stimulated-2    stimulated
# Name: condition, Length: 2911, dtype: category
# Categories (3, object): ['control', 'pred', 'stimulated']
# 0-0     pred
# 1-0     pred
# 2-0     pred
# 3-0     pred
# 4-0     pred
#         ...
# 49-0    pred
# 50-0    pred
# 51-0    pred
# 52-0    pred
# 53-0    pred
# Name: condition, Length: 936, dtype: category
# Categories (1, object): ['pred']
# ACCGAAACATTGGC-1-stimulated-2    stimulated
# TAGTCTTGAGCACT-1-stimulated-2    stimulated
# ATAGATTGTTCACT-1-stimulated-2    stimulated
# TATGTGCTTGCAGT-1-stimulated-2    stimulated
# GGAACTACTCCTCG-1-stimulated-2    stimulated
#                                     ...
# ATTTGCACGAGAGC-1-stimulated-2    stimulated
# ACATCACTCAGTCA-1-stimulated-2    stimulated
# GAGTGTTGCACACA-1-stimulated-2    stimulated
# GCGTAATGGGTAAA-1-stimulated-2    stimulated
# TACATAGAGAAGGC-1-stimulated-2    stimulated
# Name: condition, Length: 1039, dtype: category
# Categories (1, object): ['stimulated']
# TGCTGAGATGCTAG-1-control-1    control
# CAGACTGACAATCG-1-control-1    control
# GTTGGATGCTTAGG-1-control-1    control
# TTCAAGCTAGCACT-1-control-1    control
# TAACCGGAATTCCT-1-control-1    control
#                                ...
# AAGTAACTGTCAAC-1-control-1    control
# TTAGGGACTGAAGA-1-control-1    control
# TACTGTTGCTGCTC-1-control-1    control
# GACCTCACAGATCC-1-control-1    control
# CCAGCTACCCGTTC-1-control-1    control
# Name: condition, Length: 936, dtype: category
# Categories (1, object): ['control']
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0                           pred
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0                           pred
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0                           pred
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0                           pred
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0                           pred
#                                                               ...
# B7_GCAAGACTCTGATG_Hpoly.Day10_TA.Early-1-2                 Hpoly.Day10
# B7_CGCAACCTACACTG_Hpoly.Day10_Stem-1-2                     Hpoly.Day10
# B8_ACTTAGCTGACTAC_Hpoly.Day10_Endocrine-1-2                Hpoly.Day10
# B7_TTCAACACAAAGTG_Hpoly.Day10_Enterocyte.Progenitor-1-2    Hpoly.Day10
# B7_GAGTGTTGAGAATG_Hpoly.Day10_Stem-1-2                     Hpoly.Day10
# Name: condition, Length: 1396, dtype: category
# Categories (3, object): ['Control', 'Hpoly.Day10', 'pred']
# index
# B1_GTACAGTGAGAAGT_Control_Endocrine-0-0    pred
# B1_GCCTCATGAAGTAG_Control_Endocrine-0-0    pred
# B3_GTTTAAGATCCCGT_Control_Endocrine-0-0    pred
# B1_GATATCCTGTCGTA_Control_Endocrine-0-0    pred
# B1_TTAGGTCTAGTACC_Control_Endocrine-0-0    pred
#                                            ...
# B2_AATGGCTGTAGTCG_Control_Tuft-0-0         pred
# B3_TTAGGGACGGCAAG_Control_Tuft-0-0         pred
# B1_GGAGTTTGCTGGTA_Control_Tuft-0-0         pred
# B1_TTACTCGAACGCAT_Control_Tuft-0-0         pred
# B3_GGACAACTATGGTC_Control_Tuft-0-0         pred
# Name: condition, Length: 504, dtype: category
# Categories (1, object): ['pred']
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# Series([], Name: condition, dtype: category
# Categories (0, object): [])
# index
# AGGTACACGGATCT-1-control-0-0             pred
# CTATGTTGTGGTCA-1-control-0-0             pred
# GAAGCTTGATGTGC-1-control-0-0             pred
# GACGGCACAATCGC-1-control-0-0             pred
# AGGTGTTGTGTTCT-1-control-0-0             pred
#                                       ...
# CAGGAACTTGGTAC-1-stimulated-0-2    stimulated
# TAGGTTCTCGACAT-1-stimulated-0-2    stimulated
# GATTGGACTCACGA-1-stimulated-0-2    stimulated
# CACAGCCTCGTAGT-1-stimulated-0-2    stimulated
# TCGCAAGAAAACAG-1-stimulated-0-2    stimulated
# Name: condition, Length: 2886, dtype: category
# Categories (3, object): ['control', 'pred', 'stimulated']
# index
# AGGTACACGGATCT-1-control-0-0    pred
# CTATGTTGTGGTCA-1-control-0-0    pred
# GAAGCTTGATGTGC-1-control-0-0    pred
# GACGGCACAATCGC-1-control-0-0    pred
# AGGTGTTGTGTTCT-1-control-0-0    pred
#                                 ...
# AAACGGCTGGTCAT-1-control-0-0    pred
# CTCATTGATGGTAC-1-control-0-0    pred
# GTTATCTGCACTAG-1-control-0-0    pred
# TCGGTAGAATCTCT-1-control-0-0    pred
# ACATGGTGGATGAA-1-control-0-0    pred
# Name: condition, Length: 886, dtype: category
# Categories (1, object): ['pred']
# index
# TGGCACCTGGTAGG-1-stimulated-0-2    stimulated
# AAACGCACAAGGGC-1-stimulated-0-2    stimulated
# ACGATGACGAAACA-1-stimulated-0-2    stimulated
# TGAGCAACATGCTG-1-stimulated-0-2    stimulated
# TCCCGAACCGTTGA-1-stimulated-0-2    stimulated
#                                       ...
# CAGGAACTTGGTAC-1-stimulated-0-2    stimulated
# TAGGTTCTCGACAT-1-stimulated-0-2    stimulated
# GATTGGACTCACGA-1-stimulated-0-2    stimulated
# CACAGCCTCGTAGT-1-stimulated-0-2    stimulated
# TCGCAAGAAAACAG-1-stimulated-0-2    stimulated
# Name: condition, Length: 1114, dtype: category
# Categories (1, object): ['stimulated']
# index
# GACAGGGAATCTTC-1-control-0-1    control
# GTAGTGACTGACCA-1-control-0-1    control
# CTTGATTGACTACG-1-control-0-1    control
# CGCAGGTGACGCTA-1-control-0-1    control
# ATAGCTCTCGCATA-1-control-0-1    control
#                                  ...
# CTATTGACGTCAAC-1-control-0-1    control
# ACCTGGCTATCGTG-1-control-0-1    control
# GCTAGAACTCGACA-1-control-0-1    control
# AGTAAGGATCTGGA-1-control-0-1    control
# TTCAAAGAAGGTCT-1-control-0-1    control
# Name: condition, Length: 886, dtype: category
# Categories (1, object): ['control']

# %%
pbmc_WGAN_all_data.write_h5ad("WGAN_pbmc_all_data.h5ad")
hpoly_WGAN_all_data.write_h5ad("WGAN_hpoly_all_data.h5ad")
study_WGAN_all_data.write_h5ad("WGAN_study_all_data.h5ad")
